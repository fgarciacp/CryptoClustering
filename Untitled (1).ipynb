# %%
import os
# Establecer la variable de entorno para evitar la fuga de memoria en Windows
os.environ["OMP_NUM_THREADS"] = "0"

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import hvplot.pandas  
from sklearn.decomposition import PCA

# %%
# Cargar el archivo CSV en un DataFrame
df_crypto = pd.read_csv('C:/Users/Usuario/Downloads/Starter_Code (16)/Starter_Code/Resources/crypto_market_data.csv')

# %%
# Obtener las estadísticas de resumen
summary_statistics = df_crypto.describe()
summary_statistics
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
print(df_crypto.columns)
# Out:
# Index(['coin_id', 'price_change_percentage_24h', 'price_change_percentage_7d',
#        'price_change_percentage_14d', 'price_change_percentage_30d',
#        'price_change_percentage_60d', 'price_change_percentage_200d',
#        'price_change_percentage_1y'],
#       dtype='object')

# %%
# Selecciona las columnas que deseas graficar
columns_to_plot = ['price_change_percentage_24h', 'price_change_percentage_7d',
                   'price_change_percentage_14d', 'price_change_percentage_30d',
                   'price_change_percentage_60d', 'price_change_percentage_200d',
                   'price_change_percentage_1y']

# Crea un gráfico de líneas
plt.figure(figsize=(10, 6))
for column in columns_to_plot:
    plt.plot(df_crypto['coin_id'], df_crypto[column], label=column)

plt.title('Variación del Precio de las Criptomonedas')
plt.xlabel('ID de la Criptomoneda')
plt.ylabel('Cambio de Precio (%)')
plt.legend()
plt.show()

# %%
df_crypto.set_index('coin_id', inplace=True)

# %%
# Seleccionar las columnas que deseas escalar
columns_to_scale = ['price_change_percentage_24h', 'price_change_percentage_7d',
                    'price_change_percentage_14d', 'price_change_percentage_30d',
                    'price_change_percentage_60d', 'price_change_percentage_200d',
                    'price_change_percentage_1y']

# %%
# Escalar los datos
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_crypto[columns_to_scale])

# %%
# Crear un nuevo DataFrame con los datos escalados
df_scaled = pd.DataFrame(scaled_data, index=df_crypto.index, columns=columns_to_scale)

# Mostrar las primeras cinco filas del DataFrame escalado
df_scaled.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Crear un gráfico de líneas con los datos escalados
plt.figure(figsize=(10, 6))
for column in columns_to_scale:
    plt.plot(df_scaled.index, df_scaled[column], label=column)

plt.title('Variación del Precio Escalado de las Criptomonedas')
plt.xlabel('ID de la Criptomoneda')
plt.ylabel('Cambio de Precio Escalado')
plt.legend()
plt.show()

# %%
# Calcular la inercia para cada valor de k
k_values = range(1, 11) 
inertia = []

# %%
for k in k_values:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)  
    kmeans.fit(scaled_data)
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
# Crear un diccionario con los datos para trazar la curva del codo
elbow_data = {'k': k_values, 'inertia': inertia}

# %%
# Dibujar un gráfico lineal con todos los valores de inercia
plt.figure(figsize=(10, 6))
plt.plot(elbow_data['k'], elbow_data['inertia'], marker='o')
plt.title('Curva del Codo')
plt.xlabel('Número de Clústeres (k)')
plt.ylabel('Inercia')
plt.xticks(elbow_data['k'])  
plt.grid()
plt.show()

# %%
# ¿Cuál es el mejor valor para k? =  4

# %%
# Inicializar el modelo K-means con el mejor valor para k
best_k = 4  # Cambia esto al mejor valor de k que encontraste
kmeans = KMeans(n_clusters=best_k, n_init=10, random_state=42)

# %%
# Ajustar el modelo K-means utilizando el DataFrame escalado
kmeans.fit(scaled_data)
# Out:
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %%
# Predecir los clústeres para agrupar las criptomonedas
clusters = kmeans.predict(scaled_data)

# %%
df_crypto.reset_index(inplace=True)

# %%
# Crear una copia del DataFrame escalado y agregar una nueva columna con los clústeres previstos
df_scaled_with_clusters = pd.DataFrame(scaled_data, columns=columns_to_scale)
df_scaled_with_clusters['coin_id'] = df_crypto['coin_id'].values  
df_scaled_with_clusters['cluster'] = clusters

# %%
# Crear un gráfico de dispersión utilizando hvPlot
scatter_plot = df_scaled_with_clusters.hvplot.scatter(
    x='price_change_percentage_24h',
    y='price_change_percentage_7d',
    by='cluster',  
    hover_cols=['coin_id'], 
    title='Agrupamiento de Criptomonedas',
    xlabel='Cambio de Precio en 24h (%)',
    ylabel='Cambio de Precio en 7d (%)',
    height=400,
    width=600
)

# %%
# Mostrar el gráfico
scatter_plot.opts(tools=['hover'])  
scatter_plot
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %%
# Aplicar PCA
pca = PCA(n_components=3)
pca_data = pca.fit_transform(scaled_data)

# %%
# Calcular la varianza explicada
explained_variance = pca.explained_variance_ratio_
total_explained_variance = explained_variance.sum()
print("Varianza total explicada por los tres componentes principales:", total_explained_variance)
# Out:
# Varianza total explicada por los tres componentes principales: 0.8950316570309841

# %%
df_pca = pd.DataFrame(data=pca_data, index=df_crypto.index, columns=['PC1', 'PC2', 'PC3'])

# %%
df_pca
# Out:
#          PC1       PC2       PC3
# 0  -0.600667  0.842760  0.461595
# 1  -0.458261  0.458466  0.952877
# 2  -0.433070 -0.168126 -0.641752
# 3  -0.471835 -0.222660 -0.479053
# 4  -1.157800  2.041209  1.859715
# 5  -0.516534  1.388377  0.804071
# 6  -0.450711  0.517699  2.846143
# 7  -0.345600  0.729439  1.478013
# 8  -0.649468  0.432165  0.600303
# 9  -0.759014 -0.201200 -0.217653
# 10 -0.248198 -1.376252 -1.462026
# 11 -0.438408 -0.175337 -0.663388
# 12 -0.693425 -0.473815 -0.527597
# 13  0.060499  2.909404  1.498571
# 14 -0.393352 -0.108192 -0.012756
# 15 -0.796176 -0.494409  1.082812
# 16  0.064075 -1.269825 -1.098829
# 17 -0.489015 -0.732719 -0.062543
# 18 -0.306272  0.703415  1.714224
# 19 -0.513528 -0.142802 -0.656566
# 20 -0.362120 -0.986914 -0.728752
# 21 -0.604265  0.827398  0.439316
# 22 -0.413296 -0.674115 -1.076628
# 23 -0.407483 -0.212507 -0.351426
# 24  0.608974  0.563532 -1.148742
# 25 -0.450211 -0.151019 -0.647401
# 26 -0.764665 -0.517886  0.204990
# ...

# %%
# Crear una lista con el número de valores k del 1 al 12
k_values = range(1, 12)  # k de 1 a 11
inertia = []

# %%
# Calcular la inercia para cada valor de k
for k in k_values:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(df_pca)  
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
#   diccionario para trazar la curva del codo
elbow_data = {
    'k': k_values,
    'inertia': inertia
}

# %%
#  Dibujar un gráfico lineal
plt.figure(figsize=(10, 6))
plt.plot(elbow_data['k'], elbow_data['inertia'], marker='o')
plt.title('Método del Codo')
plt.xlabel('Número de Clústeres (k)')
plt.ylabel('Inercia')
plt.xticks(k_values)
plt.grid()
plt.show()

# %%
#¿Cuál es el mejor valor para ( k ) al utilizar el PCA DataFrame escalado? = 4

# %%
#¿Es diferente del mejor valor ( k ) encontrado utilizando el DataFrame escalado original?= no

# %%
#
best_k = 4

# %%
#  Inicializar el modelo K-means
kmeans = KMeans(n_clusters=best_k, n_init=10, random_state=42)

# %%
# Ajustar el modelo K-means utilizando el DataFrame PCA escalado
kmeans.fit(df_pca)
# Out:
# C:\Users\Usuario\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %%
# Paso 3: Predecir los clústeres
clusters = kmeans.predict(df_pca)

# %%
#  PCA DataFrame 
df_pca_with_clusters = pd.DataFrame(data=df_pca, index=df_crypto.index, columns=['PC1', 'PC2', 'PC3'])
df_pca_with_clusters['cluster'] = clusters
df_pca_with_clusters['coin_id'] = df_crypto.index

# %%
# gráfico de dispersión utilizando hvPlot
scatter_plot = df_pca_with_clusters.hvplot.scatter(
    x='PC1',
    y='PC2',
    by='cluster',  
    hover_cols=['coin_id'], 
    title='Agrupamiento de Criptomonedas en el Espacio PCA',
    xlabel='Componente Principal 1',
    ylabel='Componente Principal 2',
    height=400,
    width=600
)

# %%
# Mostrar el gráfico
scatter_plot.opts(tools=['hover'])
scatter_plot
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [PC1]   (PC2,coin_id)

# %%
# ¿Cuál es el impacto de utilizar menos características para agrupar los datos utilizando K-Means? =Al reducir el número de características, el modelo es más rápido.es mas  fácil de interpretar los patrones generales en los datos, aunque se pierde parte de la información original.
